# %% [markdown]
# # Exploratory Data Analysis on Ford Stock Closing Price

# %%
import pandas as pd
import numpy as np
import seaborn as sns


import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/ford_close.csv', header = None, names=['ClosingPrice'])

# %%
sns.lineplot(x=df.index,y=df['ClosingPrice'])

# %%
w5 = df.rolling(5) #rolling object containing window of 5 closing prices
